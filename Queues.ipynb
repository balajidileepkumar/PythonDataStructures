# %%
class Node:
    def __init__(self, nodeid, front, rear):
        self.nodeid = nodeid
        self.front = front
        self.tail = rear
        
class circularqueue():
    '''
    FILO
    '''
    def __init__(self):
        self.nodes = []
        
    def enque(self, value):
        y = Node(id(value))
        self.nodes.append(y)
        
    def deque(self, Node):
        self.nodes.pop(0)
        
x = circularqueue()
x.enque(1)  
print(x)
