# %% [raw]
# Unindexed
# Has Nodes
# First Node is called Head
# Last Node is called Tail
# Each Node Points to the next element
# Last Node Points to None

# %% [markdown]
# #### Using Linked List

# %% [markdown]
# #### Node Constructor

# %%
class Node():
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList():
    def __init__(self,value):
        New_Node = Node(value)
        self.head = New_Node
        self.tail = New_Node
        self.length = 1 
        
    def __str__(self):
        temp = self.head
        repr_ = ""
        while temp is not None:
            repr_ += " "+ temp.value 
            temp = temp.next
        return repr_
            
    def append(self,value):
        New_Node = Node(value)
        if(self.length ==0):
            self.head = New_Node
            self.tail = New_Node
        self.tail.next = New_Node 
        self.tail = New_Node
        self.length +=1
        
    def  prepend(self, value):
        New_Node = Node(value)
        if(self.length ==0):
            self.head = New_Node
            self.tail = New_Node
        New_Node.next = self.head
        self.head= New_Node
        self.length+=1
        
    def pop(self):#Last in First Out (removing the item appended to the last)
        if(self.length==0):
            return None
        pre_ele = self.head
        cur_ele = self.head
        while cur_ele.next:
            pre_ele = cur_ele
            cur_ele = cur_ele.next
        pre_ele.next = None
        self.tail = pre_ele
        self.length-=1
        
    def __len__(self):   
        return self.length
        
a = LinkedList('India')
print(a)
print(len(a))
a.prepend('hello')
print(a)
print(len(a))
a.append(', Happy New Year')
print(a)
print(len(a))
a.pop()
print(a)
print(len(a))
a.pop()
print(a)
print(len(a))
a.pop()
print(a)
print(len(a))

# %%
#### Double Linked List
class Node():
    def __init__(self, value):
        self.next = None
        self.prev = None
        self.value = value
        
class DoublyLinkedList():
    def __init__(self, value):
        New_Node = Node(value)
        self.head = New_Node
        self.tail = New_Node
        self.length =1

# %% [markdown]
# #### Stack

# %%
class Node():
    def __init__(self, value):
        self.next = None
        self.value = value
class Stack():
    def __init__(self, value):
        New_Node = Node(value)
        self.top = New_Node
        self.height =1
        
    def __str__(self):    
        list_items = []
        if(self.height ==0):
            return None
        temp = self.top
        while temp is not None:
            print(temp.value)
            list_items.append(str(temp.value))
            temp = temp.next
        return ", ".join(list_items)
    
    def push(self, value):
        New_Node = Node(value)
        if(self.height==0):
            self.top = New_Node
        else:
            New_Node.next = self.top
            self.top = New_Node
            self.height+=1
            
    def pop(self):
        if(self.height==0):
            return None
        else:
            temp = self.top
            self.top = self.top.next
            temp.next = None
            self.height -=1
    
mystack = Stack(10)
mystack.push(20)
mystack.push(40)
mystack.pop()
mystack.push(30)
print(mystack)
mystack.height
# Out:
# 30
# 20
# 10
# 30, 20, 10
# 3

# %%
import collections
dir(collections)
# Out:
# ['ChainMap',
#  'Counter',
#  'OrderedDict',
#  'UserDict',
#  'UserList',
#  'UserString',
#  '_Link',
#  '_OrderedDictItemsView',
#  '_OrderedDictKeysView',
#  '_OrderedDictValuesView',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_chain',
#  '_collections_abc',
#  '_count_elements',
#  '_eq',
#  '_iskeyword',
#  '_itemgetter',
#  '_proxy',
#  '_recursive_repr',
#  '_repeat',
#  '_starmap',
#  '_sys',
#  '_tuplegetter',
#  'abc',
#  'defaultdict',
#  'deque',
#  'namedtuple']
